# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/final.csv")
df.head(15)
# Out:
#     user_id signup_date plan_type  monthly_fee  avg_weekly_usage_hours  \
# 0       1.0  2023-04-15   Premium        699.0                     1.1
# 1       2.0  2023-08-27   Premium        699.0                     2.6
# 2       3.0  2023-10-12   Premium        699.0                    14.3
# 3       4.0  2023-12-11     Basic        199.0                    17.6
# 4       5.0  2023-02-14     Basic        199.0                     9.8
# 5       6.0  2024-10-05   Premium        699.0                    13.6
# 6       7.0  2023-10-24   Premium        699.0                    14.6
# 7       8.0  2024-01-09     Basic        199.0                    21.7
# 8       9.0  2023-03-15     Basic        199.0                     9.2
# 9      10.0  2024-10-17   Premium        699.0                    13.6
# 10     11.0  2023-11-20   Premium        699.0                     5.9
# 11     12.0  2024-10-20  Standard        399.0                     2.1
# 12     13.0  2024-08-21  Standard        399.0                     7.0
# 13     14.0  2023-02-18  Standard        399.0                     9.4
# 14     15.0  2024-09-02     Basic        199.0                    15.9
#
#     support_tickets  payment_failures  tenure_months  last_login_days_ago  \
# 0               4.0               1.0            8.0                 14.0
# 1               6.0               0.0           35.0                  1.0
# 2               8.0               3.0            2.0                 14.0
# 3               5.0               2.0           11.0                  9.0
# 4               5.0               2.0            6.0                 38.0
# 5               6.0               0.0           30.0                 35.0
# 6               1.0               0.0           24.0                 42.0
# 7               6.0               2.0           15.0                 29.0
# 8               4.0               5.0           24.0                 59.0
# 9               3.0               1.0           11.0                 29.0
# 10              5.0               0.0           36.0                 14.0
# 11              5.0               1.0           18.0                 41.0
# 12              3.0               5.0           10.0                 35.0
# 13              2.0               4.0           26.0                 31.0
# 14              6.0               4.0           10.0                  4.0
#
#    churn
# 0    Yes
# 1    Yes
# 2    Yes
# 3    Yes
# 4    Yes
# 5    Yes
# 6    Yes
# 7    Yes
# 8    Yes
# 9     No
# 10    No
# 11   Yes
# 12   Yes
# 13   Yes
# 14   Yes

# %%
df.shape, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 2800 non-null   float64
#  1   signup_date             2800 non-null   object
#  2   plan_type               2800 non-null   object
#  3   monthly_fee             2800 non-null   float64
#  4   avg_weekly_usage_hours  2800 non-null   float64
#  5   support_tickets         2800 non-null   float64
#  6   payment_failures        2800 non-null   float64
#  7   tenure_months           2800 non-null   float64
#  8   last_login_days_ago     2800 non-null   float64
#  9   churn                   2800 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 218.9+ KB
# ((2800, 10), None)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
sns.countplot(x=df["churn"])
plt.title("Target Distribution")
plt.show()

# %%
df.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isnull(), cbar= False)
plt.show()

# %%
corr = df.select_dtypes(include="number").corr()


plt.figure(figsize=(12,8))
sns.heatmap( corr, annot = True, fmt=".2f", cmap= "coolwarm")
plt.show()
