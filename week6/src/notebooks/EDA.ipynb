# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))


DATA_PATH = os.path.join(BASE_DIR, "src", "data", "raw", "customer_subscription_churn_usage_patterns.csv")

print(f"Checking path: {DATA_PATH}")

if os.path.exists(DATA_PATH):
    df = pd.read_csv(DATA_PATH)
    print(f"File loaded successfully! Shape: {df.shape}")
else:
    print("Error: The file still doesn't exist at that location.")
    #
    raw_folder = os.path.join(BASE_DIR, "src", "data", "raw")
    if os.path.exists(raw_folder):
        print(f"Files found in raw folder: {os.listdir(raw_folder)}")
# Out:
# Checking path: /home/priyanshurajchauhan/Desktop/Traning/week6/src/data/raw/customer_subscription_churn_usage_patterns.csv
# File loaded successfully! Shape: (2800, 10)

# %%
df.shape, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 2800 non-null   int64
#  1   signup_date             2800 non-null   object
#  2   plan_type               2799 non-null   object
#  3   monthly_fee             2789 non-null   float64
#  4   avg_weekly_usage_hours  2800 non-null   float64
#  5   support_tickets         2800 non-null   int64
#  6   payment_failures        2799 non-null   float64
#  7   tenure_months           2791 non-null   float64
#  8   last_login_days_ago     2782 non-null   float64
#  9   churn                   2800 non-null   object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 218.9+ KB
# ((2800, 10), None)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))


PROCESSED_DATA = os.path.join(BASE_DIR, "src", "data", "processed", "final.csv")

print(f"Checking path: {PROCESSED_DATA}") 

if os.path.exists(PROCESSED_DATA):
    df = pd.read_csv(PROCESSED_DATA)
    print("File loaded successfully!")
else:
    print("Error: The file still doesn't exist at that location.")
# Out:
# /home/priyanshurajchauhan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Checking path: /home/priyanshurajchauhan/Desktop/Traning/week6/src/data/processed/final.csv
# File loaded successfully!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 2800 non-null   float64
#  1   signup_date             2800 non-null   object
#  2   plan_type               2800 non-null   object
#  3   monthly_fee             2800 non-null   float64
#  4   avg_weekly_usage_hours  2800 non-null   float64
#  5   support_tickets         2800 non-null   float64
#  6   payment_failures        2800 non-null   float64
#  7   tenure_months           2800 non-null   float64
#  8   last_login_days_ago     2800 non-null   float64
#  9   churn                   2800 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 218.9+ KB

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
sns.countplot(x=df["churn"])
plt.title("Target Distribution")
plt.show()

# %%
corr = df.select_dtypes(include="number").corr()


plt.figure(figsize=(12,8))
sns.heatmap( corr, annot = True, fmt=".2f", cmap= "coolwarm")
plt.show()
